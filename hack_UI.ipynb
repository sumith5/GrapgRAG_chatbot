# %%
# %pip install --upgrade --quiet  langchain langchain-community langchain-openai langchain-experimental neo4j wikipedia tiktoken yfiles_jupyter_graphs
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.0/990.0 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 22.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.7/202.7 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.5/293.5 kB 17.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 35.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 37.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.5/373.5 kB 31.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.8/328.8 kB 26.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 15.1 MB/s eta 0:00:00
# ...

# %%
# !pip install -q streamlit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 27.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 71.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.6 MB/s eta 0:00:00

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.147.108.250

# %%
! streamlit run /content/app.py & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.147.108.250:8501
#
# Need to install the following packages:
#   localtunnel@2.0.2
# Ok to proceed? (y) y
# your url is: https://deep-camels-roll.loca.lt
# 2024-07-22 10:08:09.656 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/elements/image.py", line 385, in image_to_url
#     with open(image, "rb") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Prolificslogo.jpg'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/memory_media_file_storage.py", line 164, in _read_file
#     with open(filename, "rb") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Prolificslogo.jpg'
#
# ...

# %%
import pandas as pd
df = pd.read_excel("/content/latest.xlsx")
# Group by the Description column and sum the Quantity column for rows with the same Description
df_grouped = df.groupby('Description').sum().reset_index()
df_grouped
# Out:
#                                           Description  Quantity
# 0                             1" SINGLE WATER SERVICE   2270.00
# 1                                12" STEEL ENCASEMENT    508.00
# 2      12" STEEL ENCASEMENT BY BORE (MSUD RELOCATION)    342.00
# 3                               18" AIR RELEASE VALVE     12.00
# 4                                 18" BUTTERFLY VALVE      7.00
# 5                           18" BUTTERFLY VALVE & BOX     41.00
# 6                                   18" PVC WATERLINE   6529.00
# 7                                  18" PVC WATERLINE    5020.00
# 8                                        18" x 8" TEE      1.00
# 9                            2" AUTOMATIC FLUSH VALVE      7.00
# 10                               22.5Â° VERTICAL BEND      4.00
# 11                               30" STEEL ENCASEMENT    344.18
# 12                                          45Â° BEND     10.00
# 13                                      8"  WATERLINE   3463.43
# ...

# %%
df2 = pd.read_csv("/content/water.csv")

# %%
# Merge the DataFrames to get the sorting order
df_grouped = pd.merge(df2[['Description']], df_grouped, on='Description', how='left')

# Display the sorted DataFrame (optional)
print("\nSorted DataFrame:")
print(df_grouped)
# Out:
# Sorted DataFrame:
#                                           Description  Quantity
# 0                                    8" PVC WATERLINE       NaN
# 1                                   18" PVC WATERLINE   6529.00
# 2   8" AWWA C900 DR18 MUSTANG WATERLINE FOR RELOCA...   3867.00
# 3                                 8" GATE VALVE & BOX    108.00
# 4                           18" BUTTERFLY VALVE & BOX     41.00
# 5                            2" AUTOMATIC FLUSH VALVE      7.00
# 6                               18" AIR RELEASE VALVE     12.00
# 7   FIRE HYDRANT ASSEMBLY (INCL. LEAD, TEE, VALVE,...       NaN
# 8                                          END & PLUG     28.00
# 9           RAISE EXISTING WATER VALVE TO FINAL GRADE      5.00
# 10  REMOVE PLUG AND CONNECT TO EXISTING 18" WATERLINE      9.00
# 11   REMOVE PLUG AND CONNECT TO EXISTING 8" WATERLINE     11.00
# 12                            1" SINGLE WATER SERVICE   2270.00
# ...

# %%
# Save the grouped data to a new Excel file
output_file_path = '/content/grouped_data.csv'
df_grouped.to_csv(output_file_path, index=False)

output_file_path
# Out:
# '/content/grouped_data.csv'
